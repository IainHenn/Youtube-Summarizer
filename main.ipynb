# %%
import scrapetube
import pandas as pd 
import re
from googleapiclient.discovery import build

# %%
#Need to run youtube API and fetch a channel id given a channel id or channel url 
#Run channel id and make a dataframe of the channel's video data
#Clean the data so it looks good and has insightful numbers and values
#Figure out making a front end and implementing --> https://stackoverflow.com/questions/66589307/generating-a-chart-js-chart-with-python-data
#Need a front page that will work as a input area for user, input a channel name / url and then we take the data and output the charts

# %%
api_key = "AIzaSyBuEw-7qmVP6aTeHwHVqcpqsx80UfYt2EI"

#Using api key and youtube api, build youtube
youtube = build("youtube",'v3', developerKey = api_key)
#Make a request that grabs statistics on a given channel
request = youtube.channels().list(part = "statistics", forUsername = "Pewdiepie")
response = request.execute()

#Of the statistics, grab the userID 
items = response["items"]
items_dict = items[0]
user_ID = items_dict["id"]

# %%
#Given a user_ID, scrape all video data and put into a dataframe 
videos = scrapetube.get_channel(user_ID)
videos_DF = pd.DataFrame(videos)

# %%
videos_DF_mod = videos_DF

#Need to remove thumbnail, descriptionSnippet

# %%
videos_DF_mod.dtypes
# Out:
# videoId               object
# thumbnail             object
# title                 object
# descriptionSnippet    object
# publishedTimeText     object
# lengthText            object
# viewCountText         object
# navigationEndpoint    object
# ownerBadges           object
# trackingParams        object
# showActionMenu          bool
# shortViewCountText    object
# menu                  object
# thumbnailOverlays     object
# richThumbnail         object
# badges                object
# topStandaloneBadge    object
# dtype: object

# %%
videos_DF_mod["lengthText"].iloc[0]
# Out:
# {'accessibility': {'accessibilityData': {'label': '21 minutes, 5 seconds'}},
#  'simpleText': '21:05'}

# %%
videos_DF_mod
# Out:
#           videoId                                          thumbnail  \
# 0     kSt2QspMnG0  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 1     3XRTKZlCYSA  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 2     UMDv7gtqBYQ  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 3     f6CT2ov1I90  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4     n_Zj7ZLNuN0  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# ...           ...                                                ...
# 4532  hC7c1fhW1YM  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4533  XONXcdJ0278  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4534  lUtoLyyeOwQ  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4535  0U6ZgImZ5vo  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4536  9jeJbdVl2jI  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
#
#                                                   title  \
# 0     {'runs': [{'text': 'MAYBE'}], 'accessibility':...
# 1     {'runs': [{'text': 'Boys First Bike ride! *Fro...
# 2     {'runs': [{'text': 'I will NEver recover from ...
# 3     {'runs': [{'text': 'Minecraft is a horror game...
# 4     {'runs': [{'text': 'New Family Member!'}], 'ac...
# ...                                                 ...
# 4532  {'runs': [{'text': 'Dual Minecraft Lets Play! ...
# 4533  {'runs': [{'text': 'Dual Minecraft Lets Play! ...
# 4534  {'runs': [{'text': 'Call of Duty: Black Ops: W...
# 4535  {'runs': [{'text': 'Blacklight Tango Down: Tea...
# 4536  {'runs': [{'text': 'Minecraft Multiplayer Fun'...
#
#                                      descriptionSnippet  \
# 0     {'runs': [{'text': '#ad - Get the new Booty Pi...
# 1     {'runs': [{'text': 'Check out Nonsense x Pewdi...
# 2     {'runs': [{'text': 'Stock Up On ➡️🥤Gfuel: http...
# 3     {'runs': [{'text': 'Get exclusive NordVPN deal...
# 4     {'runs': [{'text': 'Get exclusive NordVPN deal...
# ...                                                 ...
# 4532  {'runs': [{'text': 'Thanks for SUBSCRIBING!
# S...
# 4533  {'runs': [{'text': 'Thanks for SUBSCRIBING!
#
# ...
# 4534  {'runs': [{'text': '100 SUBS THANK YOU! :D
# Hav...
# 4535  {'runs': [{'text': 'Thank YOU for subscribing ...
# 4536  {'runs': [{'text': 'My friend was going to sho...
#
#                    publishedTimeText  \
# 0       {'simpleText': '3 days ago'}
# 1      {'simpleText': '2 weeks ago'}
# 2      {'simpleText': '1 month ago'}
# 3      {'simpleText': '1 month ago'}
# 4      {'simpleText': '1 month ago'}
# ...                              ...
# 4532  {'simpleText': '13 years ago'}
# 4533  {'simpleText': '13 years ago'}
# 4534  {'simpleText': '13 years ago'}
# 4535  {'simpleText': '13 years ago'}
# 4536  {'simpleText': '13 years ago'}
#
#                                              lengthText  \
# 0     {'accessibility': {'accessibilityData': {'labe...
# 1     {'accessibility': {'accessibilityData': {'labe...
# 2     {'accessibility': {'accessibilityData': {'labe...
# 3     {'accessibility': {'accessibilityData': {'labe...
# 4     {'accessibility': {'accessibilityData': {'labe...
# ...                                                 ...
# 4532  {'accessibility': {'accessibilityData': {'labe...
# 4533  {'accessibility': {'accessibilityData': {'labe...
# 4534  {'accessibility': {'accessibilityData': {'labe...
# 4535  {'accessibility': {'accessibilityData': {'labe...
# 4536  {'accessibility': {'accessibilityData': {'labe...
#
#                            viewCountText  \
# 0      {'simpleText': '1,729,070 views'}
# 1      {'simpleText': '2,041,914 views'}
# 2      {'simpleText': '2,005,672 views'}
# 3      {'simpleText': '2,683,887 views'}
# 4      {'simpleText': '5,447,456 views'}
# ...                                  ...
# 4532     {'simpleText': '836,557 views'}
# 4533   {'simpleText': '1,974,485 views'}
# 4534   {'simpleText': '4,251,895 views'}
# 4535   {'simpleText': '1,971,196 views'}
# 4536  {'simpleText': '22,312,405 views'}
#
#                                      navigationEndpoint  \
# 0     {'clickTrackingParams': 'CPoBENwwIhMI9unr5eqVi...
# 1     {'clickTrackingParams': 'CPMBENwwIhMI9unr5eqVi...
# 2     {'clickTrackingParams': 'COwBENwwIhMI9unr5eqVi...
# 3     {'clickTrackingParams': 'COUBENwwIhMI9unr5eqVi...
# 4     {'clickTrackingParams': 'CN4BENwwIhMI9unr5eqVi...
# ...                                                 ...
# 4532  {'clickTrackingParams': 'CB4Q3DAiEwjZpc6465WIA...
# 4533  {'clickTrackingParams': 'CBcQ3DAiEwjZpc6465WIA...
# 4534  {'clickTrackingParams': 'CBAQ3DAiEwjZpc6465WIA...
# 4535  {'clickTrackingParams': 'CAkQ3DAiEwjZpc6465WIA...
# 4536  {'clickTrackingParams': 'CAIQ3DAiEwjZpc6465WIA...
#
#                                             ownerBadges  \
# 0     [{'metadataBadgeRenderer': {'icon': {'iconType...
# 1     [{'metadataBadgeRenderer': {'icon': {'iconType...
# 2     [{'metadataBadgeRenderer': {'icon': {'iconType...
# 3     [{'metadataBadgeRenderer': {'icon': {'iconType...
# 4     [{'metadataBadgeRenderer': {'icon': {'iconType...
# ...                                                 ...
# 4532  [{'metadataBadgeRenderer': {'icon': {'iconType...
# 4533  [{'metadataBadgeRenderer': {'icon': {'iconType...
# 4534  [{'metadataBadgeRenderer': {'icon': {'iconType...
# 4535  [{'metadataBadgeRenderer': {'icon': {'iconType...
# 4536  [{'metadataBadgeRenderer': {'icon': {'iconType...
#
#                                          trackingParams  showActionMenu  \
# 0     CPoBENwwIhMI9unr5eqViAMVEXtMCB2ESATSQO24stKsyN...           False
# 1     CPMBENwwIhMI9unr5eqViAMVEXtMCB2ESATSQKDCicqZ5Z...           False
# 2     COwBENwwIhMI9unr5eqViAMVEXtMCB2ESATSQISLqNvg_b...           False
# 3     COUBENwwIhMI9unr5eqViAMVEXtMCB2ESATSQN3H1N-o-6...           False
# 4     CN4BENwwIhMI9unr5eqViAMVEXtMCB2ESATSQN3xtpbZ_Z...           False
# ...                                                 ...             ...
# 4532  CB4Q3DAiEwjZpc6465WIAxXue0wIHU41ArhAg6vbwt-at5...           False
# 4533   CBcQ3DAiEwjZpc6465WIAxXue0wIHU41ArhAv7fTk53u1fFc           False
# 4534  CBAQ3DAiEwjZpc6465WIAxXue0wIHU41ArhAhPb45PKF2q...           False
# 4535  CAkQ3DAiEwjZpc6465WIAxXue0wIHU41ArhA-s3nzIiwpq...           False
# 4536  CAIQ3DAiEwjZpc6465WIAxXue0wIHU41ArhAsrSXq92t4p...           False
#
#                                      shortViewCountText  \
# 0     {'accessibility': {'accessibilityData': {'labe...
# 1     {'accessibility': {'accessibilityData': {'labe...
# 2     {'accessibility': {'accessibilityData': {'labe...
# 3     {'accessibility': {'accessibilityData': {'labe...
# 4     {'accessibility': {'accessibilityData': {'labe...
# ...                                                 ...
# 4532  {'accessibility': {'accessibilityData': {'labe...
# 4533  {'accessibility': {'accessibilityData': {'labe...
# 4534  {'accessibility': {'accessibilityData': {'labe...
# 4535  {'accessibility': {'accessibilityData': {'labe...
# 4536  {'accessibility': {'accessibilityData': {'labe...
#
#                                                    menu  \
# 0     {'menuRenderer': {'items': [{'menuServiceItemR...
# 1     {'menuRenderer': {'items': [{'menuServiceItemR...
# 2     {'menuRenderer': {'items': [{'menuServiceItemR...
# 3     {'menuRenderer': {'items': [{'menuServiceItemR...
# 4     {'menuRenderer': {'items': [{'menuServiceItemR...
# ...                                                 ...
# 4532  {'menuRenderer': {'items': [{'menuServiceItemR...
# 4533  {'menuRenderer': {'items': [{'menuServiceItemR...
# 4534  {'menuRenderer': {'items': [{'menuServiceItemR...
# 4535  {'menuRenderer': {'items': [{'menuServiceItemR...
# 4536  {'menuRenderer': {'items': [{'menuServiceItemR...
#
#                                       thumbnailOverlays  \
# 0     [{'thumbnailOverlayTimeStatusRenderer': {'text...
# 1     [{'thumbnailOverlayTimeStatusRenderer': {'text...
# 2     [{'thumbnailOverlayTimeStatusRenderer': {'text...
# 3     [{'thumbnailOverlayTimeStatusRenderer': {'text...
# 4     [{'thumbnailOverlayTimeStatusRenderer': {'text...
# ...                                                 ...
# 4532  [{'thumbnailOverlayTimeStatusRenderer': {'text...
# 4533  [{'thumbnailOverlayTimeStatusRenderer': {'text...
# 4534  [{'thumbnailOverlayTimeStatusRenderer': {'text...
# 4535  [{'thumbnailOverlayTimeStatusRenderer': {'text...
# 4536  [{'thumbnailOverlayTimeStatusRenderer': {'text...
#
#                                           richThumbnail badges  \
# 0     {'movingThumbnailRenderer': {'movingThumbnailD...    NaN
# 1     {'movingThumbnailRenderer': {'movingThumbnailD...    NaN
# 2     {'movingThumbnailRenderer': {'movingThumbnailD...    NaN
# 3     {'movingThumbnailRenderer': {'movingThumbnailD...    NaN
# 4     {'movingThumbnailRenderer': {'movingThumbnailD...    NaN
# ...                                                 ...    ...
# 4532  {'movingThumbnailRenderer': {'movingThumbnailD...    NaN
# 4533  {'movingThumbnailRenderer': {'movingThumbnailD...    NaN
# 4534  {'movingThumbnailRenderer': {'movingThumbnailD...    NaN
# 4535  {'movingThumbnailRenderer': {'movingThumbnailD...    NaN
# 4536  {'movingThumbnailRenderer': {'movingThumbnailD...    NaN
#
#      topStandaloneBadge
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 4532                NaN
# 4533                NaN
# 4534                NaN
# 4535                NaN
# 4536                NaN
#
# [4537 rows x 17 columns]

# %%
def remakeLengthText(df):
    lengthTextModified = []
    for rowVal in df["lengthText"]:
        lengthTextModified.append(rowVal["accessibility"]["accessibilityData"]["label"])
    
    df["lengthText"] = pd.DataFrame(lengthTextModified)
    return df

# %%
def remakeSingleDict(df,columnName):
    columnModified = []
    pattern = r"\{'simpleText':\s*'(.*?)'\}"
    for rowVal in df[columnName]:
        rowVal = str(rowVal)
        match = re.search(pattern,rowVal)
        
        if match:
            value = match.group(1)
            columnModified.append(value)
    
    #columnModified = pd.DataFrame(columnModified)
    #return pd.DataFrame(columnModified)
    
    df[columnName] = pd.DataFrame(columnModified)
    return df

# %%
def remakeTitle(df):
    titleColumnModified = []
    for rowVal in df["title"]:
        titleColumnModified.append(rowVal["runs"][0]["text"])
        
    df["title"] = pd.DataFrame(titleColumnModified)
    return df

# %%
videos_DF_mod = remakeLengthText(videos_DF_mod)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 videos_DF_mod = remakeLengthText(videos_DF_mod)
#
# Cell In[10], line 4, in remakeLengthText(df)
#       2 lengthTextModified = []
#       3 for rowVal in df["lengthText"]:
# ----> 4     lengthTextModified.append(rowVal["accessibility"]["accessibilityData"]["label"])
#       6 df["lengthText"] = pd.DataFrame(lengthTextModified)
#       7 return df
#
# TypeError: string indices must be integers, not 'str'

# %%
videos_DF_mod = remakeSingleDict(videos_DF_mod,"publishedTimeText")

# %%
videos_DF_mod = remakeSingleDict(videos_DF_mod,"viewCountText")

# %%
videos_DF_mod = videos_DF_mod[videos_DF_mod["publishedTimeText"].notna()]
videos_DF_mod = videos_DF_mod[videos_DF_mod["lengthText"].notna()]
videos_DF_mod = videos_DF_mod[videos_DF_mod["viewCountText"].notna()]

# %%
videos_DF_mod = remakeTitle(videos_DF_mod)

# %%
videos_DF_mod

# %%
videos_DF_mod.iloc[0]
# Out:
# videoId                                                     kSt2QspMnG0
# thumbnail             {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# title                                                             MAYBE
# descriptionSnippet    {'runs': [{'text': '#ad - Get the new Booty Pi...
# publishedTimeText                                            3 days ago
# lengthText                                        21 minutes, 5 seconds
# viewCountText                                           1,729,070 views
# navigationEndpoint    {'clickTrackingParams': 'CPoBENwwIhMI9unr5eqVi...
# ownerBadges           [{'metadataBadgeRenderer': {'icon': {'iconType...
# trackingParams        CPoBENwwIhMI9unr5eqViAMVEXtMCB2ESATSQO24stKsyN...
# showActionMenu                                                    False
# shortViewCountText    {'accessibility': {'accessibilityData': {'labe...
# menu                  {'menuRenderer': {'items': [{'menuServiceItemR...
# thumbnailOverlays     [{'thumbnailOverlayTimeStatusRenderer': {'text...
# richThumbnail         {'movingThumbnailRenderer': {'movingThumbnailD...
# badges                                                              NaN
# topStandaloneBadge                                                  NaN
# Name: 0, dtype: object
