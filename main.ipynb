# %%
import scrapetube
import pandas as pd 
import re
from googleapiclient.discovery import build 
import time
import datetime

# %%
#Need to run youtube API and fetch a channel id given a channel id or channel url 
#Run channel id and make a dataframe of the channel's video data
#Clean the data so it looks good and has insightful numbers and values
#Figure out making a front end and implementing --> https://stackoverflow.com/questions/66589307/generating-a-chart-js-chart-with-python-data
#Need a front page that will work as a input area for user, input a channel name / url and then we take the data and output the charts

# %%
api_key = "AIzaSyBuEw-7qmVP6aTeHwHVqcpqsx80UfYt2EI"

#Using api key and youtube api, build youtube
youtube = build("youtube",'v3', developerKey = api_key)
#Make a request that grabs statistics on a given channel
request = youtube.channels().list(part = "statistics", forUsername = "Pewdiepie")
response = request.execute()

#Of the statistics, grab the userID 
items = response["items"]
items_dict = items[0]
user_ID = items_dict["id"]

# %%
#Given a user_ID, scrape all video data and put into a dataframe 
videos = scrapetube.get_channel(user_ID)
videos_DF = pd.DataFrame(videos)

# %%
videos_DF_mod = videos_DF

#Need to remove thumbnail, descriptionSnippet

# %%
videos_DF_mod.dtypes
# Out:
# videoId               object
# thumbnail             object
# title                 object
# descriptionSnippet    object
# publishedTimeText     object
# lengthText            object
# viewCountText         object
# navigationEndpoint    object
# ownerBadges           object
# trackingParams        object
# showActionMenu          bool
# shortViewCountText    object
# menu                  object
# thumbnailOverlays     object
# richThumbnail         object
# badges                object
# topStandaloneBadge    object
# dtype: object

# %%
videos_DF_mod["lengthText"].iloc[0]
# Out:
# {'accessibility': {'accessibilityData': {'label': '38 minutes, 3 seconds'}},
#  'simpleText': '38:03'}

# %%
videos_DF_mod
# Out:
#           videoId                                          thumbnail  \
# 0     Fn1OeGys2L8  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 1     kSt2QspMnG0  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 2     3XRTKZlCYSA  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 3     UMDv7gtqBYQ  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4     f6CT2ov1I90  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# ...           ...                                                ...
# 4533  hC7c1fhW1YM  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4534  XONXcdJ0278  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4535  lUtoLyyeOwQ  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4536  0U6ZgImZ5vo  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4537  9jeJbdVl2jI  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
#
#                                                   title  \
# 0     {'runs': [{'text': 'I WILL NOT APOLOGIZE FOR M...
# ...

# %%
def remakeLengthText(df):
    lengthTextModified = []
    for rowVal in df["lengthText"]:
        lengthTextModified.append(rowVal["accessibility"]["accessibilityData"]["label"])
    
    df["lengthText"] = pd.DataFrame(lengthTextModified)
    return df

# %%
def remakeSingleDict(df,columnName):
    columnModified = []
    pattern = r"\{'simpleText':\s*'(.*?)'\}"
    for rowVal in df[columnName]:
        rowVal = str(rowVal)
        match = re.search(pattern,rowVal)
        
        if match:
            value = match.group(1)
            columnModified.append(value)
    
    #columnModified = pd.DataFrame(columnModified)
    #return pd.DataFrame(columnModified)
    
    df[columnName] = pd.DataFrame(columnModified)
    return df

# %%
def remakeTitle(df):
    titleColumnModified = []
    for rowVal in df["title"]:
        titleColumnModified.append(rowVal["runs"][0]["text"])
        
    df["title"] = pd.DataFrame(titleColumnModified)
    return df

# %%
def remakeThumbnail(df):
    thumbnailColumnModified = []
    for rowVal in df["thumbnail"]:
        thumbnailColumnModified.append(rowVal["thumbnails"][0]["url"])
        
    df["thumbnail"] = pd.DataFrame(thumbnailColumnModified)
    return df

# %%
videos_DF_mod = remakeLengthText(videos_DF_mod)

# %%
videos_DF_mod = remakeSingleDict(videos_DF_mod,"publishedTimeText")

# %%
videos_DF_mod = remakeSingleDict(videos_DF_mod,"viewCountText")

# %%
videos_DF_mod = videos_DF_mod[videos_DF_mod["publishedTimeText"].notna()]
videos_DF_mod = videos_DF_mod[videos_DF_mod["lengthText"].notna()]
videos_DF_mod = videos_DF_mod[videos_DF_mod["viewCountText"].notna()]

# %%
videos_DF_mod = remakeTitle(videos_DF_mod)

# %%
videos_DF_mod["thumbnail"][0]["thumbnails"][0]["url"]
# Out:
# 'https://i.ytimg.com/vi/Fn1OeGys2L8/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLANAKQvWjpRVG6mDmaSRT4fyW14hA'

# %%
videos_DF_mod
# Out:
#           videoId                                          thumbnail  \
# 0     Fn1OeGys2L8  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 1     kSt2QspMnG0  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 2     3XRTKZlCYSA  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 3     UMDv7gtqBYQ  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4     f6CT2ov1I90  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# ...           ...                                                ...
# 4523  Q0Ov47QVfg4  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4524  KhNE-Qzbeok  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4525  G_wh0vPEdgQ  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4526  762TcGx9QWQ  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
# 4527  zgemXv32HXo  {'thumbnails': [{'url': 'https://i.ytimg.com/v...
#
#                                                   title  \
# 0                    I WILL NOT APOLOGIZE FOR MY CRIMES
# ...

# %%
videos_DF_mod = remakeThumbnail(videos_DF_mod)

# %%
videos_DF_mod
# Out:
#           videoId                                          thumbnail  \
# 0     Fn1OeGys2L8  https://i.ytimg.com/vi/Fn1OeGys2L8/hqdefault.j...
# 1     kSt2QspMnG0  https://i.ytimg.com/vi/kSt2QspMnG0/hqdefault.j...
# 2     3XRTKZlCYSA  https://i.ytimg.com/vi/3XRTKZlCYSA/hqdefault.j...
# 3     UMDv7gtqBYQ  https://i.ytimg.com/vi/UMDv7gtqBYQ/hqdefault.j...
# 4     f6CT2ov1I90  https://i.ytimg.com/vi/f6CT2ov1I90/hqdefault.j...
# ...           ...                                                ...
# 4523  Q0Ov47QVfg4  https://i.ytimg.com/vi/Q0Ov47QVfg4/hqdefault.j...
# 4524  KhNE-Qzbeok  https://i.ytimg.com/vi/KhNE-Qzbeok/hqdefault.j...
# 4525  G_wh0vPEdgQ  https://i.ytimg.com/vi/G_wh0vPEdgQ/hqdefault.j...
# 4526  762TcGx9QWQ  https://i.ytimg.com/vi/762TcGx9QWQ/hqdefault.j...
# 4527  zgemXv32HXo  https://i.ytimg.com/vi/zgemXv32HXo/hqdefault.j...
#
#                                                   title  \
# 0                    I WILL NOT APOLOGIZE FOR MY CRIMES
# ...

# %%
videos_DF_mod = videos_DF_mod.drop(["publishedTimeText","descriptionSnippet","navigationEndpoint","ownerBadges","trackingParams","showActionMenu","shortViewCountText","menu","thumbnailOverlays","richThumbnail","badges","topStandaloneBadge"], axis = 1)

# %%
def fixViews(df):
    df_column_mod = df["viewCountText"].apply(lambda x: x.replace(" views", ""))
    df_column_mod = df_column_mod.apply(lambda x: x.replace(",",""))
    df_column_mod.astype("int64")
    df["viewCountText"] = df_column_mod

    return df

# %%
videos_DF_mod = fixViews(videos_DF_mod)

# %%
videos_DF_mod
# Out:
#           videoId                                          thumbnail  \
# 0     Fn1OeGys2L8  https://i.ytimg.com/vi/Fn1OeGys2L8/hqdefault.j...
# 1     kSt2QspMnG0  https://i.ytimg.com/vi/kSt2QspMnG0/hqdefault.j...
# 2     3XRTKZlCYSA  https://i.ytimg.com/vi/3XRTKZlCYSA/hqdefault.j...
# 3     UMDv7gtqBYQ  https://i.ytimg.com/vi/UMDv7gtqBYQ/hqdefault.j...
# 4     f6CT2ov1I90  https://i.ytimg.com/vi/f6CT2ov1I90/hqdefault.j...
# ...           ...                                                ...
# 4523  Q0Ov47QVfg4  https://i.ytimg.com/vi/Q0Ov47QVfg4/hqdefault.j...
# 4524  KhNE-Qzbeok  https://i.ytimg.com/vi/KhNE-Qzbeok/hqdefault.j...
# 4525  G_wh0vPEdgQ  https://i.ytimg.com/vi/G_wh0vPEdgQ/hqdefault.j...
# 4526  762TcGx9QWQ  https://i.ytimg.com/vi/762TcGx9QWQ/hqdefault.j...
# 4527  zgemXv32HXo  https://i.ytimg.com/vi/zgemXv32HXo/hqdefault.j...
#
#                                                   title  \
# 0                    I WILL NOT APOLOGIZE FOR MY CRIMES
# ...

# %%
def get_video_publish_dates(youtube, df):
    publish_dates = []

    for i in range(0, df.shape[0], 50):
        batch_ids = df["videoId"][i:i+50]
        request = youtube.videos().list(
            part='snippet',
            id=','.join(batch_ids)
        )
        response = request.execute()

        for item in response.get('items', []):
            video_id = item['id']
            publish_date = item['snippet']['publishedAt']
            publish_dates.append(publish_date)

        time.sleep(1)  # To avoid hitting rate limits

    df["publishedAt"] = pd.DataFrame(publish_dates)
    return df

# %%
#Problematic, takes too long to run 
'''def appendPublishedAt(df):
    publishedAt = []
    for rowVal in df["videoId"]:
        request2 = youtube.videos().list(part = "snippet", id = rowVal)
        response2 = request2.execute()
        publishedAt.append(response2['items'][0]['snippet']['publishedAt'])
        time.sleep(1)
    df["publishedAt"] = pd.DataFrame(publishedAt)
    return df'''
# Out:
# 'def appendPublishedAt(df):\n    publishedAt = []\n    for rowVal in df["videoId"]:\n        request2 = youtube.videos().list(part = "snippet", id = rowVal)\n        response2 = request2.execute()\n        publishedAt.append(response2[\'items\'][0][\'snippet\'][\'publishedAt\'])\n        time.sleep(1)\n    df["publishedAt"] = pd.DataFrame(publishedAt)\n    return df'

# %%
videos_DF_mod = get_video_publish_dates(youtube,videos_DF_mod)

# %%
def lengthTextModified(df):
    lengthTextSeconds = []
    lengthTextTime = []
    for rowVal in df["lengthText"]:
        pattern = r'(?:(\d+)\s*hours?,?\s*)?(?:(\d+)\s*minutes?,?\s*)?(?:(\d+)\s*seconds?)'
        match = re.search(pattern, rowVal)

        if match:
            rowHours = match.group(1) or 0
            rowMinutes = match.group(2) or 0
            rowSeconds = match.group(3) or 0 

        if rowHours != 0:
            rowHours = int(rowHours)
        if rowMinutes != 0:
            rowMinutes = int(rowMinutes)
        if rowSeconds != 0:
            rowSeconds = int(rowSeconds)

        time = datetime.time(rowHours,rowMinutes,rowSeconds)
        totalSeconds = (rowHours*3600) + (rowMinutes*60) + (rowSeconds)
        lengthTextTime.append(time)
        lengthTextSeconds.append(totalSeconds)
    
    df["lengthTextTime"] = pd.DataFrame(lengthTextTime)
    df["lengthTextSeconds"] = pd.DataFrame(lengthTextSeconds)
    return df

# %%
videos_DF_mod = lengthTextModified(videos_DF_mod)

# %%
videos_final_df = videos_DF_mod.drop(["lengthText"],axis = 1)

# %%
videos_final_df
# Out:
#           videoId                                          thumbnail  \
# 0     Fn1OeGys2L8  https://i.ytimg.com/vi/Fn1OeGys2L8/hqdefault.j...
# 1     kSt2QspMnG0  https://i.ytimg.com/vi/kSt2QspMnG0/hqdefault.j...
# 2     3XRTKZlCYSA  https://i.ytimg.com/vi/3XRTKZlCYSA/hqdefault.j...
# 3     UMDv7gtqBYQ  https://i.ytimg.com/vi/UMDv7gtqBYQ/hqdefault.j...
# 4     f6CT2ov1I90  https://i.ytimg.com/vi/f6CT2ov1I90/hqdefault.j...
# ...           ...                                                ...
# 4523  Q0Ov47QVfg4  https://i.ytimg.com/vi/Q0Ov47QVfg4/hqdefault.j...
# 4524  KhNE-Qzbeok  https://i.ytimg.com/vi/KhNE-Qzbeok/hqdefault.j...
# 4525  G_wh0vPEdgQ  https://i.ytimg.com/vi/G_wh0vPEdgQ/hqdefault.j...
# 4526  762TcGx9QWQ  https://i.ytimg.com/vi/762TcGx9QWQ/hqdefault.j...
# 4527  zgemXv32HXo  https://i.ytimg.com/vi/zgemXv32HXo/hqdefault.j...
#
#                                                   title viewCountText  \
# ...
